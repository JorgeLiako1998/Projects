# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("complete")
# Out:
# complete

# %%
asparagusdata_filepath='FAOSTAT_data_7-10-2021.csv'
asparagusdata = pd.read_csv(asparagusdata_filepath)

# %%
asparagusdata.head()
# Out:
#         Area         Element       Item  Year Unit  Value
# 0  Argentina  Area harvested  Asparagus  1961   ha  450.0
# 1  Argentina  Area harvested  Asparagus  1962   ha  495.0
# 2  Argentina  Area harvested  Asparagus  1963   ha  486.0
# 3  Argentina  Area harvested  Asparagus  1964   ha  473.0
# 4  Argentina  Area harvested  Asparagus  1965   ha  504.0

# %%
#checking missing data
asparagusdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2418 entries, 0 to 2417
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Area     2418 non-null   object
#  1   Element  2418 non-null   object
#  2   Item     2418 non-null   object
#  3   Year     2418 non-null   int64
#  4   Unit     2418 non-null   object
#  5   Value    1881 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 113.5+ KB

# %%
CMD = asparagusdata[['Year', 'Value']].copy()
CMD.head()
# Out:
#    Year  Value
# 0  1961  450.0
# 1  1962  495.0
# 2  1963  486.0
# 3  1964  473.0
# 4  1965  504.0

# %%
#Check missing data
sns.heatmap(CMD.isnull(),cbar=False,yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
#checking amount of units in DF
Unit = list(asparagusdata['Unit'].unique())
Unit
# Out:
# ['ha']

# %%
Countries = list(asparagusdata['Area'].unique())
Countries
# Out:
# ['Argentina',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Belgium-Luxembourg',
#  'Bhutan',
#  'Bulgaria',
#  'Canada',
#  'Chile',
#  'China',
#  'China, mainland',
#  'China, Taiwan Province of',
#  'Colombia',
#  'Costa Rica',
#  'Czechia',
#  'Denmark',
#  'Ecuador',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iran (Islamic Republic of)',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Jordan',
#  'Kenya',
#  'Lithuania',
#  'Luxembourg',
#  'Mexico',
#  'Morocco',
#  'Netherlands',
#  'New Zealand',
#  'North Macedonia',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Senegal',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Thailand',
#  'Turkey',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'United States of America',
#  'Zambia',
#  'Zimbabwe']

# %%
#Structure df?
df = pd.DataFrame(data=asparagusdata,columns=['Area', 'Year','Value'])
df.set_index(['Area','Year'])
# Out:
#                 Value
# Area      Year
# Argentina 1961  450.0
#           1962  495.0
#           1963  486.0
#           1964  473.0
#           1965  504.0
# ...               ...
# Zimbabwe  2015   74.0
#           2016   75.0
#           2017   75.0
#           2018   75.0
#           2019   75.0
#
# [2418 rows x 1 columns]

# %%
#list of all the countries
for countries in Countries:
        print(countries)
# Out:
# Argentina
# Australia
# Austria
# Belgium
# Belgium-Luxembourg
# Bhutan
# Bulgaria
# Canada
# Chile
# China
# China, mainland
# China, Taiwan Province of
# Colombia
# Costa Rica
# Czechia
# Denmark
# Ecuador
# Estonia
# Finland
# France
# Germany
# Greece
# Hungary
# Iran (Islamic Republic of)
# Israel
# Italy
# Japan
# Jordan
# Kenya
# Lithuania
# Luxembourg
# Mexico
# Morocco
# Netherlands
# New Zealand
# North Macedonia
# Peru
# Philippines
# Poland
# Portugal
# Romania
# Senegal
# Slovakia
# Slovenia
# Spain
# Sweden
# Switzerland
# Thailand
# Turkey
# United Kingdom of Great Britain and Northern Ireland
# United States of America
# Zambia
# Zimbabwe

# %%
#can we predict what missing values through linear regression? 
asparagusdata.isnull().sum()
# Out:
# Area         0
# Element      0
# Item         0
# Year         0
# Unit         0
# Value      537
# dtype: int64

# %%
Argentina = asparagusdata.loc[asparagusdata.Area=='Argentina']
Argentina
# Out:
#          Area         Element       Item  Year Unit   Value
# 0   Argentina  Area harvested  Asparagus  1961   ha   450.0
# 1   Argentina  Area harvested  Asparagus  1962   ha   495.0
# 2   Argentina  Area harvested  Asparagus  1963   ha   486.0
# 3   Argentina  Area harvested  Asparagus  1964   ha   473.0
# 4   Argentina  Area harvested  Asparagus  1965   ha   504.0
# 5   Argentina  Area harvested  Asparagus  1966   ha   520.0
# 6   Argentina  Area harvested  Asparagus  1967   ha   800.0
# 7   Argentina  Area harvested  Asparagus  1968   ha   810.0
# 8   Argentina  Area harvested  Asparagus  1969   ha   834.0
# 9   Argentina  Area harvested  Asparagus  1970   ha   840.0
# 10  Argentina  Area harvested  Asparagus  1971   ha   810.0
# 11  Argentina  Area harvested  Asparagus  1972   ha   860.0
# 12  Argentina  Area harvested  Asparagus  1973   ha   850.0
# 13  Argentina  Area harvested  Asparagus  1974   ha   883.0
# 14  Argentina  Area harvested  Asparagus  1975   ha   898.0
# ...

# %%
Bhutan = asparagusdata.loc[asparagusdata.Area=='Bhutan']
Bhutan
# Out:
#        Area         Element       Item  Year Unit  Value
# 236  Bhutan  Area harvested  Asparagus  1991   ha    NaN
# 237  Bhutan  Area harvested  Asparagus  1992   ha    NaN
# 238  Bhutan  Area harvested  Asparagus  1993   ha    NaN
# 239  Bhutan  Area harvested  Asparagus  1994   ha    NaN
# 240  Bhutan  Area harvested  Asparagus  1995   ha    NaN
# 241  Bhutan  Area harvested  Asparagus  1996   ha    NaN
# 242  Bhutan  Area harvested  Asparagus  1997   ha    NaN
# 243  Bhutan  Area harvested  Asparagus  1998   ha    NaN
# 244  Bhutan  Area harvested  Asparagus  1999   ha    NaN
# 245  Bhutan  Area harvested  Asparagus  2000   ha    NaN
# 246  Bhutan  Area harvested  Asparagus  2001   ha    NaN
# 247  Bhutan  Area harvested  Asparagus  2002   ha    NaN
# 248  Bhutan  Area harvested  Asparagus  2003   ha    NaN
# 249  Bhutan  Area harvested  Asparagus  2004   ha    NaN
# 250  Bhutan  Area harvested  Asparagus  2005   ha    NaN
# ...
